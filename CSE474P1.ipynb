# %% [markdown]
# <a href="https://colab.research.google.com/github/LaazAlae/NeuralNetwork/blob/main/CSE474P1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-da94f93a-6c66-4f11-a7c3-a41f186d3309" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-da94f93a-6c66-4f11-a7c3-a41f186d3309">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
# !pip install scipy numpy matplotlib

# %%
# !python nnScript.py
# Out:
# preprocess done
#
#  Training set Accuracy:95.652%
#
#  Validation set Accuracy:95.02000000000001%
#
#  Test set Accuracy:95.19999999999999%
# Starting hyperparameter tuning...
# Testing h=4, lambda=0
# Val acc: 74.16%, Time: 49.28s
# Testing h=4, lambda=10
# Val acc: 67.95%, Time: 45.58s
# Testing h=4, lambda=20
# Val acc: 82.72%, Time: 46.09s
# Testing h=4, lambda=30
# Val acc: 69.84%, Time: 41.81s
# Testing h=4, lambda=40
# Val acc: 77.29%, Time: 46.89s
# Testing h=4, lambda=50
# Val acc: 64.21%, Time: 40.73s
# Testing h=8, lambda=0
# Val acc: 87.01%, Time: 46.29s
# Testing h=8, lambda=10
# Val acc: 85.73%, Time: 45.70s
# Testing h=8, lambda=20
# Val acc: 89.97%, Time: 45.25s
# Testing h=8, lambda=30
# Val acc: 88.14%, Time: 46.28s
# Testing h=8, lambda=40
# Val acc: 89.18%, Time: 44.30s
# Testing h=8, lambda=50
# Val acc: 89.41%, Time: 43.65s
# Testing h=12, lambda=0
# Val acc: 91.37%, Time: 56.86s
# Testing h=12, lambda=10
# Val acc: 90.25%, Time: 55.22s
# ...

# %%
# !python facennScript.py
# Out:
#  Training set Accuracy:85.75829383886256%
#
#  Validation set Accuracy:84.61538461538461%
#
#  Test set Accuracy:86.37395912187736%

# %%
# !python deepnnScript.py
# Out:
# Using cpu device
#
# --------- Testing with 3 hidden layers ---------
# Epoch 1
# -------------------------------
# loss: 0.693822  [    0/21100]
# loss: 0.693156  [10000/21100]
# loss: 0.693035  [20000/21100]
# Epoch 2
# -------------------------------
# loss: 0.692137  [    0/21100]
# loss: 0.694759  [10000/21100]
# loss: 0.691710  [20000/21100]
# Epoch 3
# -------------------------------
# loss: 0.692832  [    0/21100]
# loss: 0.693822  [10000/21100]
# loss: 0.692373  [20000/21100]
# Epoch 4
# -------------------------------
# loss: 0.693813  [    0/21100]
# loss: 0.693335  [10000/21100]
# loss: 0.693792  [20000/21100]
# Epoch 5
# -------------------------------
# loss: 0.692527  [    0/21100]
# loss: 0.691962  [10000/21100]
# loss: 0.691644  [20000/21100]
# Epoch 6
# -------------------------------
# loss: 0.691951  [    0/21100]
# loss: 0.692568  [10000/21100]
# loss: 0.691807  [20000/21100]
# Epoch 7
# -------------------------------
# loss: 0.691349  [    0/21100]
# ...

# %%
from google.colab import files

files.download('nnScript.py')
files.download('params.pickle')
files.download('tuning_results.png')
files.download('deepnnScript.py')
files.download('facennScript.py')
files.download('cnnScript.py')
files.download('mnist_all.mat')
files.download('face_all.pickle')
